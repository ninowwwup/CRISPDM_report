# %% [markdown]
# <a href="https://colab.research.google.com/github/ninowwwup/CRISPDM_report/blob/main/CRISPDM_MODELING_INPUTS_%26_OUTPUTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MODELING

# %% [markdown]
# ![Frame 1 (3).png](data:image/png;base64,...)

# %% [markdown]
# ## SELECT MODELING TECHNIQUE

# %% [markdown]
# ### Modeling Technique

# %% [markdown]
# ### Modeling Assumptions

# %% [markdown]
# ## GENERATE TEST DISIGN

# %% [markdown]
# ### Test Design

# %% [markdown]
# # BULD MODEL

# %% [markdown]
# ### Parameter Settings

# %% [markdown]
# ### Models

# %% [markdown]
# ### Model Description

# %% [markdown]
# # ASSES MODEL

# %% [markdown]
# ### Model Assessment

# %% [markdown]
# ### Revised Paramter Settings
