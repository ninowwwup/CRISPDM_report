# %% [markdown]
# <a href="https://colab.research.google.com/github/ninowwwup/CRISPDM_report/blob/main/CRISPDM_BUSINESS_UNDERSTANDING_INPUT_%26_OUTPUTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BUSINESS UNDERSTANDING

# %% [markdown]
# ![Business Undestanding Tasks.png](data:image/png;base64,...)

# %% [markdown]
# # DETERMINE BUSINESS OBJECTIVES

# %% [markdown]
# ### Background

# %% [markdown]
# ### Business Objective

# %% [markdown]
# ### Business Success Criteria

# %% [markdown]
# ### Reusability, Adaptibility & Versatility Goals

# %% [markdown]
# # ASSESS SITUATION

# %% [markdown]
# ### Inventory of Resources

# %% [markdown]
# ### Requeriments, Assumtions & Constraints

# %% [markdown]
# ### Risks & Contingencies

# %% [markdown]
# ### Terminology

# %% [markdown]
# ### Costs & Benefits

# %% [markdown]
# # DETERMINE DATA MINING GOALS

# %% [markdown]
# ### Data Mining & Context-aware Goals

# %% [markdown]
# ### Data Mining & Context-aware Success Criteria

# %% [markdown]
# # PRODUCE PROJECT PLAN

# %% [markdown]
# ### Project Plan

# %% [markdown]
# ### Initial Assess of Tools & Tecniques
