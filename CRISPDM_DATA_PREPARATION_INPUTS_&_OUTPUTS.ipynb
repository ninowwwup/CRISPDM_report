# %% [markdown]
# <a href="https://colab.research.google.com/github/ninowwwup/CRISPDM_report/blob/main/CRISPDM_DATA_PREPARATION_INPUTS_%26_OUTPUTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DATA PREPARATION

# %% [markdown]
# ![Data Preparation Tasks (1).png](data:image/png;base64,...)

# %% [markdown]
# ### Dataset

# %% [markdown]
# ### Data Description

# %% [markdown]
# # SELECT DATA

# %% [markdown]
# ### Rationale for Inclusion / Exclusion

# %% [markdown]
# # CLEAN DATA

# %% [markdown]
# ### Data Cleaning Report

# %% [markdown]
# # CONSTRUCT DATA

# %% [markdown]
# ### Derived Attributes

# %% [markdown]
# ### Generated Records

# %% [markdown]
# # INTEGRATE DATA

# %% [markdown]
# ### Merged Data

# %% [markdown]
# # FORMAT DATA

# %% [markdown]
# ### Reformatted Data
